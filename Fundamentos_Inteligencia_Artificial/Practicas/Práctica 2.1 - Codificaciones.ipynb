# %% [markdown]
# ## Codificación de Cantor
#
# #### Cantor 2_1 y Cantor 3_1

# %%
def cantor2_1(x,y):
    sol = (x+y)*(x+y+1)/2 + y

    return sol

def cantor3_1(x,y,z):
   sol = cantor2_1(x,cantor2_1(y,z))

   return sol

# %%
ej1 = cantor2_1(1,1)
ej2 = cantor2_1(1,4)
ej3 = cantor3_1(1,1,1)

print(ej1)
print(ej2)
print(ej3)
# Out:
# 4.0
# 19.0
# 19.0

# %% [markdown]
# ### Ejercicio 1. Establezca la Decodificación de Cantor

# %%
def cantor1_2_2(y):  # Segunda componente
    sol = 0 #ToDo
    return sol

def cantor1_2_1(x):  # Primera componente
    sol = 0 #ToDo
    return sol  

def d(x):               #Función auxiliar
     #ToDo
    return 0

print (cantor1_2_2 (0))
print (cantor1_2_1 (0))

# %% [markdown]
# ### Ejercicio 2. Establezca la Codificación/Decodificación de Gödel

# %% [markdown]
# ## codi, Codi y CODI

# %%
# Posible implementacion de codi
def codi(s, index):
    sol = 0
    i = s[index][1]
    j = s[index][2]

    if s[index][0] == 0:                        #Xi := 0
        sol = 5 * (i - 1)
    elif s[index][0] == 1: 
        sol = 5 * cantor2_1(i - 1, j - 1) + 1  #Xi := Xj
    elif s[index][0] == 2:
        sol = 5 * cantor2_1(i - 1, j - 1) + 2   #Xi := Xj +1
    elif s[index][0] == 3:
        sol = 5 * cantor2_1(i - 1, j - 1) + 3  #Xi := Xj -1
    #elif s[index][0] == 4:
        #sol = 5 * cantor2_1(i - 1, Codi()) + 4 #WHILE #ToDo

    return sol

def Codi():
    #ToDo
    return 0

def CODI():
    #ToDo
    return 0


s = [ [3, 1, 1] ] ## Operación, i, j X1 := X1 -1

print(codi(s, 0))

# %% [markdown]
# ### Ejercicio 3. Termina la implementación de codi, Codi, CODI
