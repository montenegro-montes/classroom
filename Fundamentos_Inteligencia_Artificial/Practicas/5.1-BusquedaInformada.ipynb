# %% [markdown]
# ## Implementación de los algoritmos Greedy y A*
#
# - La frontera esta vez ha sido creado mediante una cola de prioridad para favorecer el diseño del algoritmo y que funciones con A* y Greedy.
# - Las dos implementaciones usan el algoritmo best_first_search.

# %%
from queue import PriorityQueue

class Node:
    def __init__(self, state, parent=None, cost=0):
        self.state = state
        self.parent = parent
        self.cost = cost

    def __str__(self):
        return f"Node(state={self.state}, parent={self.parent}, cost={self.cost})"    

    def __lt__(self, other):
        return self.cost < other.cost

def imprimir_frontera (frontier):
    print("\tFrontera actual:")
    for priority, n in frontier.queue:
        print(f"\t\tPrioridad: {priority}, Estado: {n.state}, Costo del camino: {n.cost}")


def best_first_search(problem, f):
    node = Node(problem.initial_state)
    frontier = PriorityQueue()
    frontier.put((f(node), node))
    reached = {problem.initial_state: node}

    while not frontier.empty():

        imprimir_frontera   (frontier);
        
        _, node = frontier.get()

        if problem.is_goal(node.state):
            return node
        
        
        for child_state, step_cost in problem.expand(node.state):
            child = Node(child_state, node, node.cost + step_cost)
            if child_state not in reached or child.cost < reached[child_state].cost:
                reached[child_state] = child
                frontier.put((f(child), child))

    return "failure"

def print_solution(solution_node):
    if solution_node == "failure":
        print("No se encontró solución.")
        return

    path = []
    current_node = solution_node
    while current_node is not None:
        path.append((current_node.state, current_node.cost))
        current_node = current_node.parent

    path.reverse()  # Invertir el orden para imprimir desde el inicio hasta el objetivo
    total_cost = path[-1][1]  # Costo total es el costo del último nodo en el camino
    print("Camino de la solución:")
    for state, cost in path:
        print(f"Estado: {state}, Costo: {cost}")

    print("Costo total de la solución:", total_cost)

# %% [markdown]
# # Implementación del Problema del Mapa de Rumania
#
# - Ejercicio: Completa el grafo de Rumania.
# - Observa la como cambia la implementación de Greedy y A*.
# - Estudia como evoluciona la estructura frontera.
# - Realiza un grafo con los pueblos de Málaga, puedes ayudarte de la información en https://espana.mejoresrutas.com/

# %%
class MapaRumaniaProblem:
    def __init__(self, graph, initial_state, goal_state, heuristic):
        self.graph = graph
        self.initial_state = initial_state
        self.goal_state = goal_state
        self.heuristic = heuristic

    def is_goal(self, state):
        return state == self.goal_state

    def expand(self, state):
        return [(child_state, cost) for child_state, cost in self.graph[state].items()]

# Definimos el grafo de Rumania
graph = {
    'Arad': {'Zerind': 75, 'Sibiu': 140, 'Timisoara': 118},
    'Zerind': {'Arad': 75, 'Oradea': 71},
    'Oradea': {'Zerind': 71, 'Sibiu': 151},
    'Sibiu': {'Arad': 140, 'Oradea': 151, 'Fagaras': 99, 'Rimnicu Vilcea': 80},
    'Timisoara': {'Arad': 118, 'Lugoj': 111},
    'Lugoj': {'Timisoara': 111, 'Mehadia': 70},
    'Mehadia': {'Lugoj': 70, 'Drobeta': 75},
    'Drobeta': {'Mehadia': 75, 'Craiova': 120},
    'Craiova': {'Drobeta': 120, 'Rimnicu Vilcea': 146, 'Pitesti': 138},
    'Rimnicu Vilcea': {'Sibiu': 80, 'Craiova': 146, 'Pitesti': 97},
    'Fagaras': {'Sibiu': 99, 'Bucharest': 211},
    'Pitesti': {'Rimnicu Vilcea': 97, 'Craiova': 138, 'Bucharest': 101},
    'Bucharest': {'Fagaras': 211, 'Pitesti': 101}
}

# Definimos la función heurística
def heuristic(city):
    distances_to_bucharest = {
        'Arad': 366,
        'Bucharest': 0,
        'Craiova': 160,
        'Drobeta': 242,
        'Eforie':161,
        'Fagaras': 176,
        'Giurgiu':77,
        'Hirsova':151,
        'Iasi':226,
        'Lugoj': 244,
        'Mehadia': 241,
        'Neamt':234,
        'Oradea': 380,
        'Pitesti':100,
        'Rimnicu Vilcea': 193,
        'Sibiu': 253,
        'Timisoara': 329,
        'Urziceni':80,
        'Vaslui':199,
        'Zerind': 374
    }
    return distances_to_bucharest[city]

# Creamos una instancia del problema
problem = MapaRumaniaProblem(graph, 'Arad', 'Bucharest', heuristic)

# Ejemplo de uso
#print("Nodo inicial:", problem.initial_state)
#print("Nodo final:", problem.goal_state)
#print("Expandir desde Arad:", problem.expand('Arad'))
#print("Heurística para Bucharest:", problem.heuristic('Bucharest'))

def fG(node):
    return  problem.heuristic(node.state)

solution_node_greedy = best_first_search(problem, fG)
print("Solución con Greedy Best First Search:")
print_solution(solution_node_greedy)


def fA(node):
    return node.cost + problem.heuristic(node.state)


solution_node_a_star = best_first_search(problem, fA)
print("\nSolución con A* Search:")
print_solution(solution_node_a_star)

# %% [markdown]
# ## Ejercicio: Utilizando como base el problema de Rumania, realiza los problemas 1 y 2 de las transparencias.

# %%
class Ejercicio1:
    def __init__(self, graph, initial_state, goal_state, heuristic):
        self.graph = graph
        self.initial_state = initial_state
        self.goal_state = goal_state
        self.heuristic = heuristic

    def is_goal(self, state):
        return state == self.goal_state

    def expand(self, state):
        return [(child_state, cost) for child_state, cost in self.graph[state].items()]

# Definimos el grafo del Problema 1 y Problema 2
graph = {
    
}

# Definimos la función heurística
def heuristic(city):
    distances_to_goal = {
        
    }
    return distances_to_goal[city]

# Creamos una instancia del problema
problem = Ejercicio1(graph, 'A', 'G', heuristic)

def fG(node):
    return  problem.heuristic(node.state)

solution_node_greedy = best_first_search(problem, fG)
print("Solución con Greedy Best First Search:")
print_solution(solution_node_greedy)


def fA(node):
    return node.cost + problem.heuristic(node.state)


solution_node_a_star = best_first_search(problem, fA)
print("\nSolución con A* Search:")
print_solution(solution_node_a_star)

# %% [markdown]
# ### Problema Puzzle 8:
# - Mira la implementación del puzzle 8
# - El problema utiliza la heurística de piezas mal colocadas.
# - Crea la heurística Manhattan, compara las ejecuciones.

# %%
class Puzzle8Problem:
    def __init__(self, initial_state, goal_state):
        self.initial_state = tuple(initial_state)
        self.goal_state = tuple(goal_state)

    def is_goal(self, state):
      return state == self.goal_state

    def expand(self, state):
     children = []
     zero_index = state.index(0)
     row, col = divmod(zero_index, 3)  # Convertir el índice en fila y columna
     moves = [(1, 0), (-1, 0), (0, 1), (0, -1)]  # Movimientos: arriba, abajo, izquierda, derecha
     for move in moves:
        new_row, new_col = row + move[0], col + move[1]
        if 0 <= new_row < 3 and 0 <= new_col < 3:  # Verificar límites
            new_index = new_row * 3 + new_col
            new_state = list(state)
            new_state[zero_index], new_state[new_index] = new_state[new_index], new_state[zero_index]
            children.append((tuple(new_state), 1))  # Agregar el nuevo estado y el costo de 1
            
     return children


# Definir el estado inicial y el estado objetivo del puzzle 8
initial_state = [1, 2, 0, 3, 4, 5, 6, 7, 8]
goal_state    = [0, 1, 2, 3, 4, 5, 6, 7, 8]

# Crear una instancia del problema del puzzle 8
puzzle_problem = Puzzle8Problem(initial_state, goal_state)

# Definir la función heurística de la distancia de Manhattan
def heuristic_Manhattan(state):
    return null  

# Función heurística  de piezas malcolocadas
def misplaced_tiles_heuristic(state):
    goal_state = [0, 1, 2, 3, 4, 5, 6, 7, 8]
    misplaced = 0
    for i in range(len(state)):  
        if state[i] != goal_state[i] and state[i] != 0:
            misplaced += 1  
    return misplaced  



# Función f para usar con Greedy Best First Search 
def f(node):
    return misplaced_tiles_heuristic(node.state)

# Función f para usar con A*
def fA(node):
    return node.cost + misplaced_tiles_heuristic(node.state)


# Imprimir la solución encontrada
print("Solución con Greedy Best First Search:")
solution_greedy = best_first_search(puzzle_problem, f)
print_solution(solution_greedy)

print("\nSolución con A* Search:")
solution_astar = best_first_search(puzzle_problem, fA)
print_solution(solution_astar)
